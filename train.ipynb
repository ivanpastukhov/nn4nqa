# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import pandas as pd
import logging
import collections
import numpy as np
from model.model import QAMatching

logging.basicConfig(level=logging.INFO)
USE_CUDA = torch.cuda.is_available()
logging.info('USE_CUDA: {}'.format(USE_CUDA))
device = torch.device("cuda" if USE_CUDA else "cpu")

df_train = pd.read_csv('./data/WikiQACorpus/WikiQA-train.tsv', sep='\t')
df_test = pd.read_csv('./data/WikiQACorpus/WikiQA-test.tsv', sep='\t')
print('Shape_train: ', df_train.shape)
print('Shape_test: ', df_test.shape)
df_train.head(12)
# Out:
# INFO:root:USE_CUDA: True
# Shape_train:  (20347, 7)
# Shape_test:  (6116, 7)
#    QuestionID                                           Question DocumentID  \
# 0          Q1                      how are glacier caves formed?         D1
# 1          Q1                      how are glacier caves formed?         D1
# 2          Q1                      how are glacier caves formed?         D1
# 3          Q1                      how are glacier caves formed?         D1
# 4          Q1                      how are glacier caves formed?         D1
# 5          Q2  How are the directions of the velocity and for...         D2
# 6          Q2  How are the directions of the velocity and for...         D2
# 7          Q2  How are the directions of the velocity and for...         D2
# 8          Q2  How are the directions of the velocity and for...         D2
# 9          Q2  How are the directions of the velocity and for...         D2
# 10         Q2  How are the directions of the velocity and for...         D2
# 11         Q2  How are the directions of the velocity and for...         D2
#
#       DocumentTitle SentenceID  \
# 0      Glacier cave       D1-0
# 1      Glacier cave       D1-1
# 2      Glacier cave       D1-2
# 3      Glacier cave       D1-3
# 4      Glacier cave       D1-4
# 5   Circular motion       D2-0
# 6   Circular motion       D2-1
# 7   Circular motion       D2-2
# 8   Circular motion       D2-3
# 9   Circular motion       D2-4
# 10  Circular motion       D2-5
# 11  Circular motion       D2-6
#
#                                              Sentence  Label
# 0   A partly submerged glacier cave on Perito More...      0
# 1           The ice facade is approximately 60 m high      0
# 2           Ice formations in the Titlis glacier cave      0
# 3   A glacier cave is a cave formed within the ice...      1
# 4   Glacier caves are often called ice caves , but...      0
# 5   In physics , circular motion is a movement of ...      0
# 6   It can be uniform, with constant angular rate ...      0
# 7   The rotation around a fixed axis of a three-di...      0
# 8   The equations of motion describe the movement ...      0
# 9   Examples of circular motion include: an artifi...      0
# 10  Since the object's velocity vector is constant...      0
# 11  Without this acceleration, the object would mo...      0

# %%
sub = r"[^A-Za-z]+"
df_train.loc[:,'Question'] = df_train.loc[:, 'Question'].apply(lambda x: re.sub(sub, ' ', x).strip().lower())
df_train.loc[:,'Sentence'] = df_train.loc[:, 'Sentence'].apply(lambda x: re.sub(sub, ' ', x).strip().lower())
df_test.loc[:,'Question'] = df_test.loc[:, 'Question'].apply(lambda x: re.sub(sub, ' ', x).strip().lower())
df_test.loc[:,'Sentence'] = df_test.loc[:, 'Sentence'].apply(lambda x: re.sub(sub, ' ', x).strip().lower())
df_train.head()
# Out:
#   QuestionID                      Question DocumentID DocumentTitle  \
# 0         Q1  how are glacier caves formed         D1  Glacier cave
# 1         Q1  how are glacier caves formed         D1  Glacier cave
# 2         Q1  how are glacier caves formed         D1  Glacier cave
# 3         Q1  how are glacier caves formed         D1  Glacier cave
# 4         Q1  how are glacier caves formed         D1  Glacier cave
#
#   SentenceID                                           Sentence  Label
# 0       D1-0  a partly submerged glacier cave on perito more...      0
# 1       D1-1             the ice facade is approximately m high      0
# 2       D1-2          ice formations in the titlis glacier cave      0
# 3       D1-3  a glacier cave is a cave formed within the ice...      1
# 4       D1-4  glacier caves are often called ice caves but t...      0

# %%
class Voc:
    def __init__(self):
        self.token2index = {'<PAD>':0, '<SOS>':1, '<EOS>':2, '<UNK>':3}
        self.index2token = {v:k for k, v in self.token2index.items()}
        self.voclen = len(self.token2index)
        self.__lookslike_len__ = 10
    
    def extend_vocab(self, iterable):
        if not isinstance(iterable, collections.Iterable):
            raise ValueError('Value must be an iterable.')
        else:
            iterable = set(iterable)
            iterable = iterable - self.token2index.keys()
            ids = range(self.voclen, len(iterable)+self.voclen)
            self.token2index.update(dict(zip(iterable, ids)))
            self.index2token = {v:k for k, v in self.token2index.items()}
            self.voclen = len(self.token2index)
            
    def __call__(self):
        print('Vocabulary size: ', self.voclen)
        print('token2index looks like: ', list(self.token2index.items())[:self.__lookslike_len__], ', ...')
        print('index2token looks like: ', list(self.index2token.items())[:self.__lookslike_len__], ', ...')

# %%
df_train.head()
# Out:
#   QuestionID                      Question DocumentID DocumentTitle  \
# 0         Q1  how are glacier caves formed         D1  Glacier cave
# 1         Q1  how are glacier caves formed         D1  Glacier cave
# 2         Q1  how are glacier caves formed         D1  Glacier cave
# 3         Q1  how are glacier caves formed         D1  Glacier cave
# 4         Q1  how are glacier caves formed         D1  Glacier cave
#
#   SentenceID                                           Sentence  Label
# 0       D1-0  a partly submerged glacier cave on perito more...      0
# 1       D1-1             the ice facade is approximately m high      0
# 2       D1-2          ice formations in the titlis glacier cave      0
# 3       D1-3  a glacier cave is a cave formed within the ice...      1
# 4       D1-4  glacier caves are often called ice caves but t...      0

# %%
df_test.head()
# Out:
#   QuestionID                                         Question DocumentID  \
# 0         Q0  how african americans were immigrated to the us         D0
# 1         Q0  how african americans were immigrated to the us         D0
# 2         Q0  how african americans were immigrated to the us         D0
# 3         Q0  how african americans were immigrated to the us         D0
# 4         Q0  how african americans were immigrated to the us         D0
#
#                               DocumentTitle SentenceID  \
# 0  African immigration to the United States       D0-0
# 1  African immigration to the United States       D0-1
# 2  African immigration to the United States       D0-2
# 3  African immigration to the United States       D0-3
# 4  African immigration to the United States       D0-4
#
#                                             Sentence  Label
# 0  african immigration to the united states refer...      0
# 1  the term african in the scope of this article ...      0
# 2  from the immigration and nationality act of to...      0
# 3  african immigrants in the united states come f...      0
# 4  they include people from different national li...      0

# %%
voc = Voc()
for colname in ['Question', 'Sentence']:
    print('Name of column: ', colname)
    s = map(lambda x: x.split(), df_train.loc[:, colname])
    s = set(itertools.chain.from_iterable(s))
    print('Size before vocabulary extending: ', voc.voclen)
    voc.extend_vocab(s)
    print('Size after vocabulary extending: ', voc.voclen)
# Out:
# Name of column:  Question
# Size before vocabulary extending:  4
# Size after vocabulary extending:  3947
# Name of column:  Sentence
# Size before vocabulary extending:  3947
# Size after vocabulary extending:  29340

# %%
# %%time
df_train.loc[:, 'Question_encoded'] = df_train.loc[:, 'Question'].apply(
    lambda x: [voc.token2index.get(i, voc.token2index['<UNK>']) for i in x.split()])
df_train.loc[:, 'Sentence_encoded'] = df_train.loc[:, 'Sentence'].apply(
    lambda x: [voc.token2index.get(i, voc.token2index['<UNK>']) for i in x.split()])

df_test.loc[:, 'Question_encoded'] = df_test.loc[:, 'Question'].apply(
    lambda x: [voc.token2index.get(i, voc.token2index['<UNK>']) for i in x.split()])
df_test.loc[:, 'Sentence_encoded'] = df_test.loc[:, 'Sentence'].apply(
    lambda x: [voc.token2index.get(i, voc.token2index['<UNK>']) for i in x.split()])
# Out:
# CPU times: user 480 ms, sys: 20 ms, total: 500 ms
# Wall time: 509 ms

# %%
df_train.head()
# Out:
#   QuestionID                      Question DocumentID DocumentTitle  \
# 0         Q1  how are glacier caves formed         D1  Glacier cave
# 1         Q1  how are glacier caves formed         D1  Glacier cave
# 2         Q1  how are glacier caves formed         D1  Glacier cave
# 3         Q1  how are glacier caves formed         D1  Glacier cave
# 4         Q1  how are glacier caves formed         D1  Glacier cave
#
#   SentenceID                                           Sentence  Label  \
# 0       D1-0  a partly submerged glacier cave on perito more...      0
# 1       D1-1             the ice facade is approximately m high      0
# 2       D1-2          ice formations in the titlis glacier cave      0
# 3       D1-3  a glacier cave is a cave formed within the ice...      1
# 4       D1-4  glacier caves are often called ice caves but t...      0
#
#                 Question_encoded  \
# 0  [1634, 2170, 732, 2720, 3143]
# 1  [1634, 2170, 732, 2720, 3143]
# 2  [1634, 2170, 732, 2720, 3143]
# 3  [1634, 2170, 732, 2720, 3143]
# 4  [1634, 2170, 732, 2720, 3143]
#
#                                     Sentence_encoded
# 0  [1896, 24391, 16338, 732, 5902, 2422, 28026, 8...
# 1           [71, 3216, 19270, 908, 21302, 544, 1069]
# 2            [3216, 17771, 98, 71, 11296, 732, 5902]
# 3  [1896, 732, 5902, 908, 1896, 5902, 3143, 157, ...
# 4  [732, 2720, 2170, 2858, 595, 3216, 2720, 15509...

# %%
df_test.head()
# Out:
#   QuestionID                                         Question DocumentID  \
# 0         Q0  how african americans were immigrated to the us         D0
# 1         Q0  how african americans were immigrated to the us         D0
# 2         Q0  how african americans were immigrated to the us         D0
# 3         Q0  how african americans were immigrated to the us         D0
# 4         Q0  how african americans were immigrated to the us         D0
#
#                               DocumentTitle SentenceID  \
# 0  African immigration to the United States       D0-0
# 1  African immigration to the United States       D0-1
# 2  African immigration to the United States       D0-2
# 3  African immigration to the United States       D0-3
# 4  African immigration to the United States       D0-4
#
#                                             Sentence  Label  \
# 0  african immigration to the united states refer...      0
# 1  the term african in the scope of this article ...      0
# 2  from the immigration and nationality act of to...      0
# 3  african immigrants in the united states come f...      0
# 4  they include people from different national li...      0
#
#                               Question_encoded  \
# 0  [1634, 3915, 1380, 2315, 3, 3045, 71, 1751]
# 1  [1634, 3915, 1380, 2315, 3, 3045, 71, 1751]
# 2  [1634, 3915, 1380, 2315, 3, 3045, 71, 1751]
# 3  [1634, 3915, 1380, 2315, 3, 3045, 71, 1751]
# 4  [1634, 3915, 1380, 2315, 3, 3045, 71, 1751]
#
#                                     Sentence_encoded
# 0  [3915, 10943, 3045, 71, 240, 1689, 5124, 3045,...
# 1  [71, 1968, 3915, 98, 71, 7008, 704, 1199, 1748...
# 2  [808, 71, 10943, 2741, 2828, 1790, 704, 3045, ...
# 3  [3915, 3173, 98, 71, 240, 1689, 2439, 808, 290...
# 4  [1589, 60, 2100, 808, 2937, 2075, 12822, 1933,...

# %%
Q_MAXLEN = df_train.Question_encoded.apply(len).max()
S_MAXLEN = df_train.Sentence_encoded.apply(len).max()

def pad_sequence(seq, max_len, padding=0, cut_last=True):
    seq = seq + [padding] * (max_len - len(seq))
    if cut_last:
        seq = seq[:max_len]
    else:
        seq = seq[-max_len:]
    assert len(seq) == max_len
    return np.array(seq)

df_train.loc[:, 'Question_encoded'] = df_train.Question_encoded.apply(lambda x: pad_sequence(x, Q_MAXLEN))
df_train.loc[:, 'Sentence_encoded'] = df_train.Sentence_encoded.apply(lambda x: pad_sequence(x, S_MAXLEN))

df_test.loc[:, 'Question_encoded'] = df_test.Question_encoded.apply(lambda x: pad_sequence(x, Q_MAXLEN))
df_test.loc[:, 'Sentence_encoded'] = df_test.Sentence_encoded.apply(lambda x: pad_sequence(x, S_MAXLEN))

# %%
df_train
# Out:
#       QuestionID                                           Question  \
# 0             Q1                       how are glacier caves formed
# 1             Q1                       how are glacier caves formed
# 2             Q1                       how are glacier caves formed
# 3             Q1                       how are glacier caves formed
# 4             Q1                       how are glacier caves formed
# 5             Q2  how are the directions of the velocity and for...
# 6             Q2  how are the directions of the velocity and for...
# 7             Q2  how are the directions of the velocity and for...
# 8             Q2  how are the directions of the velocity and for...
# 9             Q2  how are the directions of the velocity and for...
# 10            Q2  how are the directions of the velocity and for...
# 11            Q2  how are the directions of the velocity and for...
# 12            Q5                           how did apollo creed die
# 13            Q5                           how did apollo creed die
# 14            Q5                           how did apollo creed die
# 15            Q5                           how did apollo creed die
# 16            Q5                           how did apollo creed die
# 17            Q5                           how did apollo creed die
# 18            Q5                           how did apollo creed die
# 19            Q5                           how did apollo creed die
# 20            Q6            how long is the term for federal judges
# 21            Q6            how long is the term for federal judges
# 22            Q6            how long is the term for federal judges
# 23            Q6            how long is the term for federal judges
# 24            Q6            how long is the term for federal judges
# 25            Q6            how long is the term for federal judges
# 26            Q6            how long is the term for federal judges
# 27            Q7        how a beretta model pistols magazines works
# 28            Q7        how a beretta model pistols magazines works
# 29            Q7        how a beretta model pistols magazines works
# ...          ...                                                ...
# 20317      Q3041            where was blue mountain state filmed at
# 20318      Q3041            where was blue mountain state filmed at
# 20319      Q3041            where was blue mountain state filmed at
# 20320      Q3041            where was blue mountain state filmed at
# 20321      Q3041            where was blue mountain state filmed at
# 20322      Q3042                    when was apple computer founded
# 20323      Q3042                    when was apple computer founded
# 20324      Q3042                    when was apple computer founded
# 20325      Q3042                    when was apple computer founded
# 20326      Q3042                    when was apple computer founded
# 20327      Q3042                    when was apple computer founded
# 20328      Q3042                    when was apple computer founded
# 20329      Q3042                    when was apple computer founded
# 20330      Q3042                    when was apple computer founded
# 20331      Q3042                    when was apple computer founded
# 20332      Q3042                    when was apple computer founded
# 20333      Q3042                    when was apple computer founded
# 20334      Q3043                      what is section eight housing
# 20335      Q3043                      what is section eight housing
# 20336      Q3043                      what is section eight housing
# 20337      Q3043                      what is section eight housing
# 0      a partly submerged glacier cave on perito more...      0
# 1                 the ice facade is approximately m high      0
# 2              ice formations in the titlis glacier cave      0
# 3      a glacier cave is a cave formed within the ice...      1
# 4      glacier caves are often called ice caves but t...      0
# 5      in physics circular motion is a movement of an...      0
# 6      it can be uniform with constant angular rate o...      0
# 7      the rotation around a fixed axis of a three di...      0
# 8      the equations of motion describe the movement ...      0
# 9      examples of circular motion include an artific...      0
# 10     since the object s velocity vector is constant...      0
# 11     without this acceleration the object would mov...      0
# 12     apollo creed is a fictional character from the...      0
# 13                        he was played by carl weathers      0
# 14     creed had multiple nicknames including the mas...      0
# 15     urban legend states that apollo creed s name i...      0
# 16     all of apollo s championship fights were sched...      0
# 17     championship fights did not convert from round...      0
# 18     rocky balboa is often wrongly credited with po...      0
# 19     balboa s signature colors were black and gold ...      0
# 20     in the united states the title of federal judg...      0
# 21     in addition to the supreme court of the united...      0
# 22     every judge appointed to such a court may be c...      0
# 23     all of these judges described thus far are ref...      0
# 24     in addition judges of the court of internation...      0
# 25     other judges serving in the federal courts inc...      0
# 26               see article i and article iii tribunals      0
# 27     the beretta a bobcat is a small pocket sized s...      0
# 28     production began in late solely in the beretta...      0
# 29     it is a further development of the beretta mod...      0
# ...                                                  ...    ...
# 20317  the series producers include chris romano and ...      0
# 20318  the series is about a fictional university blu...      0
# 20319  it portrays certain aspects of american univer...      0
# 20320  in february it was reported that blue mountain...      0
# 20321  in march ed marinaro stated that he is working...      0
# 20322  apple inc formerly apple computer inc is an am...      0
# 20323  its best known hardware products are the mac l...      0
# 20324  its software includes the os x and ios operati...      0
# 20325  the company was founded on april and incorpora...      1
# 20326  the word computer was removed from its name on...      0
# 20327  apple is the world s second largest informatio...      0
# 20328  fortune magazine named apple the most admired ...      0
# 20329  however the company has received criticism for...      0
# 20330  apple maintains retail stores in fourteen coun...      0
# 20331  it is the second largest publicly traded corpo...      0
# 20332  the company had permanent full time employees ...      0
# 20333   its worldwide annual revenue in totalled billion      0
# 20334                 section housing in the south bronx      0
# 20335  section of the housing act of often simply kno...      1
# 20336  it operates through several programs the large...      1
# 20337  the us department of housing and urban develop...      0
# 20338  the housing choice voucher program provides te...      0
# 20339  it also allows individuals to apply their mont...      0
# 20340             the maximum allowed voucher is a month      0
# 20341  section also authorizes a variety of project b...      0
# 20342  a tenant who leaves a subsidized project will ...      0
# 20343  the united states department of housing and ur...      0
# 20344  restaurants categorized by type and informatio...      0
# 20345             u s federal reserve notes in the mid s      0
# 20346  the history of the united states dollar covers...      0
#
#                                         Question_encoded  \
# 0      [1634, 2170, 732, 2720, 3143, 0, 0, 0, 0, 0, 0...
# 1      [1634, 2170, 732, 2720, 3143, 0, 0, 0, 0, 0, 0...
# 2      [1634, 2170, 732, 2720, 3143, 0, 0, 0, 0, 0, 0...
# 3      [1634, 2170, 732, 2720, 3143, 0, 0, 0, 0, 0, 0...
# 4      [1634, 2170, 732, 2720, 3143, 0, 0, 0, 0, 0, 0...
# 5      [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 6      [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 7      [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 8      [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 9      [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 10     [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 11     [1634, 2170, 71, 872, 704, 71, 2595, 2741, 288...
# 12     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
# 13     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
# 14     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
# 15     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
# 16     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
# 17     [1634, 871, 1319, 65, 2113, 0, 0, 0, 0, 0, 0, ...
#
# 24     [98, 17099, 3795, 704, 71, 1577, 704, 2503, 14...
# 25     [2460, 3795, 9061, 98, 71, 1461, 8049, 14594, ...
# 26     [1157, 1748, 252, 2741, 1748, 6441, 24023, 0, ...
# 27     [71, 1082, 1896, 9287, 908, 1896, 1152, 9240, ...
# 28     [453, 15057, 98, 322, 4099, 98, 71, 1082, 3683...
# 29     [525, 908, 1896, 18133, 2354, 704, 71, 1082, 4...
# ...                                                  ...
# 20317  [71, 1288, 3473, 60, 3082, 28673, 2741, 5732, ...
# 20318  [71, 1288, 908, 328, 1896, 21616, 581, 2758, 3...
# 20319  [525, 26272, 7551, 27830, 704, 417, 581, 503, ...
# 20320  [98, 23072, 525, 1673, 15122, 2091, 2758, 393,...
# 20321  [98, 1667, 1775, 24209, 23183, 2091, 3410, 908...
# 20322  [355, 7860, 7808, 355, 3768, 7860, 908, 557, 4...
# 20323  [2186, 3266, 2033, 25846, 28941, 2170, 71, 252...
# 20324  [2186, 8578, 14181, 71, 14036, 2776, 2741, 272...
# 20325  [71, 1397, 1673, 3090, 2422, 2492, 2741, 5040,...
# 20326  [71, 2377, 3768, 1673, 2163, 808, 2186, 1346, ...
# 20327  [355, 908, 71, 2053, 3590, 1705, 1328, 2127, 2...
# 20328  [11376, 2755, 2124, 355, 71, 3887, 28066, 1397...
# 20329  [15961, 71, 1397, 458, 10478, 2802, 836, 2186,...
# 20330  [355, 5507, 6483, 2810, 98, 15185, 1511, 2663,...
# 20331  [525, 908, 71, 1705, 1328, 25009, 19017, 2811,...
# 20332  [71, 1397, 515, 19309, 216, 2984, 15232, 2741,...
# 20333  [2186, 11096, 2658, 4712, 98, 22256, 9216, 0, ...
# 20334  [1472, 3579, 98, 71, 37, 13811, 0, 0, 0, 0, 0,...
# 20335  [1472, 704, 71, 3579, 1790, 704, 2858, 20158, ...
# 20336  [525, 28405, 3474, 4136, 9458, 71, 1328, 704, ...
# 20337  [71, 1751, 2936, 704, 3579, 2741, 12070, 2354,...
# 20338  [71, 3579, 9772, 16511, 2993, 5161, 13062, 298...
# 20339  [525, 16845, 4131, 24191, 3045, 2434, 3716, 17...
# 20340  [71, 11641, 17225, 16511, 908, 1896, 494, 0, 0...
# 20341  [1472, 16845, 9114, 1896, 18166, 704, 641, 298...
# 20342  [1896, 13062, 3491, 3034, 1896, 7124, 641, 285...
# 20343  [71, 240, 1689, 2936, 704, 3579, 2741, 12070, ...
# 20344  [5219, 4743, 2651, 3637, 2741, 2127, 328, 5591...
# 20345  [3683, 3590, 1461, 24687, 17000, 98, 71, 9248,...
# 20346  [71, 424, 704, 71, 240, 1689, 177, 2778, 1626,...
#
# [20347 rows x 9 columns]

# %%
df_test
# Out:
#      QuestionID                                           Question DocumentID  \
# 0            Q0    how african americans were immigrated to the us         D0
# 1            Q0    how african americans were immigrated to the us         D0
# 2            Q0    how african americans were immigrated to the us         D0
# 3            Q0    how african americans were immigrated to the us         D0
# 4            Q0    how african americans were immigrated to the us         D0
# 5            Q0    how african americans were immigrated to the us         D0
# 6            Q3                         how large were early jails         D3
# 7            Q3                         how large were early jails         D3
# 8            Q3                         how large were early jails         D3
# 9            Q3                         how large were early jails         D3
# 10           Q3                         how large were early jails         D3
# 11           Q3                         how large were early jails         D3
# 12           Q3                         how large were early jails         D3
# 13           Q3                         how large were early jails         D3
# 14           Q3                         how large were early jails         D3
# 15           Q3                         how large were early jails         D3
# 16           Q3                         how large were early jails         D3
# 17           Q4                             how a water pump works         D4
# 18           Q4                             how a water pump works         D4
# 19           Q4                             how a water pump works         D4
# 20           Q4                             how a water pump works         D4
# 21           Q4                             how a water pump works         D4
# 22           Q4                             how a water pump works         D4
# 23          Q20          how old was sue lyon when she made lolita        D20
# 24          Q20          how old was sue lyon when she made lolita        D20
# 25          Q20          how old was sue lyon when she made lolita        D20
# 26          Q20          how old was sue lyon when she made lolita        D20
# 27          Q20          how old was sue lyon when she made lolita        D20
# 28          Q33                         how are antibodies used in        D33
# 29          Q33                         how are antibodies used in        D33
# ...         ...                                                ...        ...
# 6086      Q3015                 what is the life span of june bugs      D2783
# 6087      Q3015                 what is the life span of june bugs      D2783
# 6088      Q3015                 what is the life span of june bugs      D2783
# 6089      Q3015                 what is the life span of june bugs      D2783
# 6090      Q3015                 what is the life span of june bugs      D2783
# 6091      Q3015                 what is the life span of june bugs      D2783
# 6092      Q3015                 what is the life span of june bugs      D2783
# 6093      Q3015                 what is the life span of june bugs      D2783
# 6094      Q3015                 what is the life span of june bugs      D2783
# 6095      Q3015                 what is the life span of june bugs      D2783
# 6096      Q3015                 what is the life span of june bugs      D2783
# 6097      Q3015                 what is the life span of june bugs      D2783
# 6098      Q3015                 what is the life span of june bugs      D2783
# 6099      Q3015                 what is the life span of june bugs      D2783
# 6100      Q3015                 what is the life span of june bugs      D2783
# 6101      Q3015                 what is the life span of june bugs      D2783
# 6102      Q3015                 what is the life span of june bugs      D2783
# 6103      Q3015                 what is the life span of june bugs      D2783
# 6104      Q3015                 what is the life span of june bugs      D2783
# 6105      Q3015                 what is the life span of june bugs      D2783
# 6106      Q3026  who is the youngest female to give birth world...        D71
# 6107      Q3045                               what is an open mare      D2809
# 6108      Q3045                               what is an open mare      D2809
# 6109      Q3045                               what is an open mare      D2809
# 6110      Q3045                               what is an open mare      D2809
# 6111      Q3045                               what is an open mare      D2809
# 6112      Q3045                               what is an open mare      D2809
# 6113      Q3045                               what is an open mare      D2809
# 6114      Q3045                               what is an open mare      D2809
# 6115      Q3045                               what is an open mare      D2809
#
#                                  DocumentTitle SentenceID  \
# 0     African immigration to the United States       D0-0
# 1     African immigration to the United States       D0-1
# 2     African immigration to the United States       D0-2
# 3     African immigration to the United States       D0-3
# 4     African immigration to the United States       D0-4
# 5     African immigration to the United States       D0-5
# 6                                       Prison       D3-0
# 7                                       Prison       D3-1
# 8                                       Prison       D3-2
# 9                                       Prison       D3-3
# 10                                      Prison       D3-4
# 11                                      Prison       D3-5
# 12                                      Prison       D3-6
# 13                                      Prison       D3-7
# 14                                      Prison       D3-8
# 15                                      Prison       D3-9
# 16                                      Prison      D3-10
# 17                                        Pump       D4-0
# 18                                        Pump       D4-1
# 19                                        Pump       D4-2
# 20                                        Pump       D4-3
# 21                                        Pump       D4-4
# 22                                        Pump       D4-5
# 23                          Lolita (1962 film)      D20-0
# 24                          Lolita (1962 film)      D20-1
# 25                          Lolita (1962 film)      D20-2
# 26                          Lolita (1962 film)      D20-3
# 27                          Lolita (1962 film)      D20-4
# 28                                    antibody      D33-0
# 29                                    antibody      D33-1
# ...                                        ...        ...
# 6086                                  June bug    D2783-0
# 6087                                  June bug    D2783-1
# 6088                                  June bug    D2783-2
# 6089                                  June bug    D2783-3
# 6090                                  June bug    D2783-4
# 6091                                  June bug    D2783-5
# 6092                                  June bug    D2783-6
# 6093                                  June bug    D2783-7
# 6094                                  June bug    D2783-8
# 6095                                  June bug    D2783-9
# 6096                                  June bug   D2783-10
# 6097                                  June bug   D2783-11
# 6098                                  June bug   D2783-12
# 6099                                  June bug   D2783-13
# 6100                                  June bug   D2783-14
# 6101                                  June bug   D2783-15
# 6102                                  June bug   D2783-16
# 6103                                  June bug   D2783-17
# 6104                                  June bug   D2783-18
# 6105                                  June bug   D2783-19
# 6106            List of youngest birth mothers      D71-0
# 6107                                      Mare    D2809-0
# 6108                                      Mare    D2809-1
# 6109                                      Mare    D2809-2
# 6110                                      Mare    D2809-3
# 6111                                      Mare    D2809-4
# 6112                                      Mare    D2809-5
# 6113                                      Mare    D2809-6
# 6114                                      Mare    D2809-7
# 6115                                      Mare    D2809-8
#
#                                                Sentence  Label  \
# 0     african immigration to the united states refer...      0
# 1     the term african in the scope of this article ...      0
# 2     from the immigration and nationality act of to...      0
# 3     african immigrants in the united states come f...      0
# 4     they include people from different national li...      0
# 5     as such african immigrants are to be distingui...      1
# 6     a prison from old french prisoun also known as...      0
# 7     imprisonment or incarceration is a legal penal...      0
# 8     other terms used are penitentiary correctional...      0
# 9     in some legal systems some of these terms have...      0
# 10    a criminal suspect who has been charged with o...      0
# 11    a criminal defendant may also be held in priso...      0
# 12    if found guilty a defendant will be convicted ...      0
# 13    as well as convicted or suspected criminals pr...      0
# 14    prisons may also be used as a tool of politica...      0
# 15    in times of war or conflict prisoners of war m...      0
# 16    a prison system is the organizational arrangem...      0
# 17                    a small electrically powered pump      0
# 18    a large electrically driven pump electropump f...      0
# 19    a pump is a device that moves fluids liquids o...      0
# 20    pumps can be classified into three major group...      0
# 21    pumps operate by some mechanism typically reci...      1
# 22    pumps operate via many energy sources includin...      0
# 23    lolita is a comedy drama film by stanley kubri...      0
# 24    the film stars james mason as humbert humbert ...      0
# 25    due to the mpaa s restrictions at the time the...      0
# 26    the actress who played lolita sue lyon was fou...      1
# 27    kubrick later commented that had he realized h...      0
# 28    each antibody binds to a specific antigen an i...      0
# 29    an antibody ab also known as an immunoglobulin...      1
# ...                                                 ...    ...
# 6086                   june bug or junebug may refer to      0
# 6087                                            beetles      0
# 6088  phyllophaga genus a genus of beetles in the su...      0
# 6089  the green june beetle cotinis nitida of the so...      0
# 6090  the ten lined june beetle polyphylla decemline...      0
# 6091  the figeater beetle cotinis mutabilis of the w...      0
# 6092  the european chafer rhizotrogus majalis amphim...      0
# 6093                                              songs      0
# 6094                                 junebug by the b s      0
# 6095  junebug from the album good morning spider by ...      0
# 6096                          junebug by robert francis      0
# 6097                                june bug by melvins      0
# 6098                                         other uses      0
# 6099                                junebug film a film      0
# 6100  the subject of the documentary white lines and...      0
# 6101  june bug wife of bucky bug a disney animated c...      0
# 6102               junebug a funky winkerbean character      0
# 6103  aea june bug an early aircraft designed by gle...      0
# 6104            june bug cocktail an alcoholic cocktail      0
# 6105           junebug a nickname for dale earnhardt jr      0
# 6106  this is a list of known biological mothers und...      0
# 6107                               a broodmare and foal      0
# 6108    a mare is an adult female horse or other equine      0
# 6109  in most cases a mare is a female horse over th...      0
# 6110  however in thoroughbred horse racing a mare is...      0
# 6111  the word can also be used for other female equ...      0
# 6112            a broodmare is a mare used for breeding      0
# 6113        a horse s female parent is known as its dam      0
# 6114  an adult male horse is called a stallion or if...      0
# 6115  occasionally the term horse is used in a restr...      0
#
#                                        Question_encoded  \
# 0     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 1     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 2     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 3     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 4     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 5     [1634, 3915, 1380, 2315, 3, 3045, 71, 1751, 0,...
# 6     [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 7     [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 8     [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 9     [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 10    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 11    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 12    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 13    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 14    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 15    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 16    [1634, 1983, 2315, 3488, 19437, 0, 0, 0, 0, 0,...
# 17    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 18    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 19    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 20    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 21    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 22    [1634, 1896, 955, 3744, 3308, 0, 0, 0, 0, 0, 0...
# 23    [1634, 2818, 1673, 10866, 3, 1850, 1108, 1538,...
# 24    [1634, 2818, 1673, 10866, 3, 1850, 1108, 1538,...
# 25    [1634, 2818, 1673, 10866, 3, 1850, 1108, 1538,...
# 26    [1634, 2818, 1673, 10866, 3, 1850, 1108, 1538,...
# 27    [1634, 2818, 1673, 10866, 3, 1850, 1108, 1538,...
# 28    [1634, 2170, 3446, 189, 98, 0, 0, 0, 0, 0, 0, ...
# 29    [1634, 2170, 3446, 189, 98, 0, 0, 0, 0, 0, 0, ...
# ...                                                 ...
# 6086  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6087  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6088  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6089  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6090  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6091  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6092  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6093  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6094  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6095  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6096  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6097  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6098  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6099  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6100  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6101  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6102  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6103  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6104  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6105  [1266, 908, 71, 503, 14336, 704, 626, 1918, 0,...
# 6106  [3491, 908, 71, 17613, 3343, 3045, 3600, 1048,...
# 6107  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6108  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6109  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6110  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6111  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6112  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6113  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6114  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
# 6115  [1266, 908, 557, 1660, 21093, 0, 0, 0, 0, 0, 0...
#
#                                        Sentence_encoded
# 0     [3915, 10943, 3045, 71, 240, 1689, 5124, 3045,...
# 1     [71, 1968, 3915, 98, 71, 7008, 704, 1199, 1748...
# 2     [808, 71, 10943, 2741, 2828, 1790, 704, 3045, ...
# 3     [3915, 3173, 98, 71, 240, 1689, 2439, 808, 290...
# 4     [1589, 60, 2100, 808, 2937, 2075, 12822, 1933,...
# 5     [2663, 24159, 3915, 3173, 2170, 3045, 1900, 25...
# 6     [1896, 4331, 808, 2818, 28614, 3, 16845, 2033,...
# 7     [9933, 2282, 15137, 908, 1896, 3165, 16429, 20...
# 8     [2460, 3532, 189, 2170, 15271, 21480, 22066, 3...
# 9     [98, 463, 3165, 3501, 463, 704, 5591, 3532, 20...
# 10    [1896, 3081, 11925, 3491, 458, 476, 945, 2110,...
# 11    [1896, 3081, 5739, 8543, 16845, 1900, 3050, 98...
# 12    [609, 59, 23212, 1896, 5739, 2850, 1900, 16881...
